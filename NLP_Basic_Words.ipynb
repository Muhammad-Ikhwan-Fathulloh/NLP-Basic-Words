# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Ikhwan-Fathulloh/NLP-Basic-Words/blob/main/NLP_Basic_Words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Workshop and Competition Computer Vision**

# %% [markdown]
# **Natural Language Processing**

# %% [markdown]
# Nama = Muhammad Ikhwan Fathulloh
# <br>
# NPM = 19552011024
# <br>
# Kelas = TIFRP19 CID A
# <br>
# Jurusan = Teknik Informatika

# %% [markdown]
# NLP untuk Merubah halaman web menjadi kata dasar dengan ploting kata dasar yang sering muncul di halaman web
# <br>
# Dengan melakukan tahapan proses
# 1. String
# 2. Cleansing
# 3. Stemming
# 4. Tokenizing
# 5. Stopwords

# %% [markdown]
# **Import and Install module, Library**

# %%
# Scripping Web
import requests

# Manipulation String
import string
import re

# Memisahkan layer dari inner HTML
from bs4 import BeautifulSoup

# Natural Language Processing Techniques
import nltk

# Stopwords
from nltk.corpus import stopwords

# Install Library Sastrawi
# !pip install Sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %% [markdown]
# **String and Cleansing**

# %%
# Request data in web
web = requests.get('https://wartakota.tribunnews.com').text
soup = BeautifulSoup(web)

# Remove tag script and style in html
for i in soup(['script','style']):
    i.decompose()

teks = ''.join(soup.stripped_strings)
print(teks)
# Out:
# Wartakotalive.com - Berita Terkini JakartaTribunnews.comMinggu, 13 Maret 2022CariNetworkTribunnews.comTribunnewsWiki.comTribunStyle.comTribunTravel.comTribunWow.comTribunNewsmaker.comTribun-Video.comTribunJualBeli.comTribunHealth.comTribunTrends.comTribunJakarta.comWartaKotalive.comTribunBekasi.comTribunBanten.comTribunTangerang.comTribunnewsDepok.comTribunJabar.idTribunnewsBogor.comTribunCirebon.comTribunJateng.comTribunSolo.comTribunBanyumas.comTribunMataram.comTribun-Pantura.comTribunJogja.comTribunJatim.comSurya.co.idSuryaMalang.comTribunMataraman.comTribunMadura.comTribun-Bali.comSerambiNews.comProhaba.coTribunnewsSultra.comTribun-Medan.comSripoku.comBangkaPos.comTribunBatam.idPosBelitung.coBabelNews.idTribunPadang.comTribunBengkulu.comTribunPekanbaru.comTribunJambi.comTribunSumsel.comTribunLampung.co.idPos-Kupang.comTribunFlores.comBanjarmasinPost.co.idTribunKaltim.coTribunKalteng.comTribunKaltara.comTribunManado.co.idTribunGorontalo.comTribun-Sulbar.comTribunPontianak.co.idTri
# ...

# %% [markdown]
# **Stemming**

# %%
teks = teks.lower()
teks = re.sub(r"\d+","",teks)
teks = teks.translate(str.maketrans("","",string.punctuation))
teks = teks.strip()

factory = StemmerFactory()
stemmer = factory.create_stemmer()
output = stemmer.stem(teks)
print(output)
# Out:
# wartakotalivecom berita kini jakartatribunnewscomminggu maret ... epapergramediacomgramedia digitalikuti kamiyoutubefacebookinstagramtwittergoogle newshiprofilekirim imageslogoutloginbelum punya akunmendaftarbreaking newshomenewsjakartapertamina jbbbogor sunmoribogortangerangbekasidepokwartabolaselebthe jakvideoepaperlainnyapemilulapsusbisnispublic servicesportsuper balllifestyleotomotifiklan bariswartakotawikicomindeks beritatravelakomodasikulinerdestinasishoppingticketingwartakotatravelcomtopstoriesviral akbp sarly sollu henti eksekusi rumah kuasa hukum promo jsm indomaret maret harga hemat keju sarden beras laku begal ibu hamil di bekas ringkus nyata sangka belum pernah perempuan pimpin jakarta jadi alas taufik muncul bawa senjata tulis arab geng risi para remaja di indeks beritaindeks fotoperang rusia ukrainakisah cinta vladimir putinalina kabaeva wanita uzbekistan raih emas olimpiadeperang rusia ukrainaancaman keri rusia akan hancur bantu militer ke ukraina karena jadi target sa
# ...

# %% [markdown]
# **Tokenizing**

# %%
tokens = [t for t in output.split()]
print(tokens)
# Out:
# ['wartakotalivecom', 'berita', 'kini', 'jakartatribunnewscomminggu', 'maret', '...', 'epapergramediacomgramedia', 'digitalikuti', 'kamiyoutubefacebookinstagramtwittergoogle', 'newshiprofilekirim', 'imageslogoutloginbelum', 'punya', 'akunmendaftarbreaking', 'newshomenewsjakartapertamina', 'jbbbogor', 'sunmoribogortangerangbekasidepokwartabolaselebthe', 'jakvideoepaperlainnyapemilulapsusbisnispublic', 'servicesportsuper', 'balllifestyleotomotifiklan', 'bariswartakotawikicomindeks', 'beritatravelakomodasikulinerdestinasishoppingticketingwartakotatravelcomtopstoriesviral', 'akbp', 'sarly', 'sollu', 'henti', 'eksekusi', 'rumah', 'kuasa', 'hukum', 'promo', 'jsm', 'indomaret', 'maret', 'harga', 'hemat', 'keju', 'sarden', 'beras', 'laku', 'begal', 'ibu', 'hamil', 'di', 'bekas', 'ringkus', 'nyata', 'sangka', 'belum', 'pernah', 'perempuan', 'pimpin', 'jakarta', 'jadi', 'alas', 'taufik', 'muncul', 'bawa', 'senjata', 'tulis', 'arab', 'geng', 'risi', 'para', 'remaja', 'di', 'indeks', 'beritaindek
# ...

# %% [markdown]
# **Stopwords**

# %%
nltk.download()
clean_tokens = tokens[:]
for token in tokens:
  if token in stopwords.words('indonesian'):
    clean_tokens.remove(token)

freq = nltk.FreqDist(clean_tokens)
for key, val in freq.items():
  print(str(key) + ":" + str(val))

freq.plot(30)
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> q
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# wartakotalivecom:1
# berita:1
# jakartatribunnewscomminggu:1
# maret:2
# ...:1
# epapergramediacomgramedia:1
# digitalikuti:1
# kamiyoutubefacebookinstagramtwittergoogle:1
# newshiprofilekirim:1
# imageslogoutloginbelum:1
# akunmendaftarbreaking:1
# newshomenewsjakartapertamina:1
# jbbbogor:1
# sunmoribogortangerangbekasidepokwartabolaselebthe:1
# jakvideoepaperlainnyapemilulapsusbisnispublic:1
# servicesportsuper:1
# ...

# %% [markdown]
# Kesimpulan :
# <br>
# Pada hasil akhir dilakukan visualisasi data untuk menampilkan kata dasar yang sering muncul, dimana kata dasar jam yang paling sering muncul.
